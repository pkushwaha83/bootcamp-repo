# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import scipy.stats as st
from pprint import pprint

# Import API key
from api_keys import weather_api_key
print(weather_api_key)
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# a3f6e2005dea83ba1a0f337c4dd8b42d

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
#print(cities)
# Out:
# 609

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1
# Save config information.
print("Beginning Data Retrieval ")
print("-----------------------------")

base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, do below things...
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : atuona
# Processing Record 2 of Set 1 : rikitea
# City not found. Skipping...
# Processing Record 3 of Set 1 : itupiranga
# Processing Record 4 of Set 1 : kodinsk
# Processing Record 5 of Set 1 : yellowknife
# Processing Record 6 of Set 1 : mahebourg
# Processing Record 7 of Set 1 : nikolskoye
# Processing Record 8 of Set 1 : klaksvik
# Processing Record 9 of Set 1 : pachino
# Processing Record 10 of Set 1 : narsaq
# Processing Record 11 of Set 1 : upernavik
# City not found. Skipping...
# Processing Record 12 of Set 1 : pilar
# Processing Record 13 of Set 1 : wanaka
# Processing Record 14 of Set 1 : puerto ayora
# Processing Record 15 of Set 1 : gushikawa
# City not found. Skipping...
# Processing Record 16 of Set 1 : ponta do sol
# Processing Record 17 of Set 1 : thompson
# Processing Record 18 of Set 1 : visnes
# Processing Record 19 of Set 1 : bluff
# Processing Record 20 of Set 1 : vaslui
# Processing Record 21 of Set 1 : beipiao
# Processing Record 22 of Set 1 : airai
# Processing Record 23 of Set 1 : saint george
# Processing Record 24 of Set 1 : punta arenas
# Processing Record 25 of Set 1 : hobart
# Processing Record 26 of Set 1 : naze
# Processing Record 27 of Set 1 : khatanga
# Processing Record 28 of Set 1 : haicheng
# Processing Record 29 of Set 1 : mar del plata
# Processing Record 30 of Set 1 : busselton
# Processing Record 31 of Set 1 : port alfred
# Processing Record 32 of Set 1 : kirkwall
# Processing Record 33 of Set 1 : jijiga
# Processing Record 34 of Set 1 : hokitika
# Processing Record 35 of Set 1 : ushuaia
# City not found. Skipping...
# Processing Record 36 of Set 1 : richards bay
# Processing Record 37 of Set 1 : gadwal
# Processing Record 38 of Set 1 : nanortalik
# Processing Record 39 of Set 1 : baykit
# Processing Record 40 of Set 1 : albany
# Processing Record 41 of Set 1 : kodiak
# Processing Record 42 of Set 1 : bredasdorp
# Processing Record 43 of Set 1 : inirida
# Processing Record 44 of Set 1 : moose factory
# City not found. Skipping...
# Processing Record 45 of Set 1 : barrow
# Processing Record 46 of Set 1 : strezhevoy
# City not found. Skipping...
# Processing Record 47 of Set 1 : castro
# Processing Record 48 of Set 1 : kapaa
# Processing Record 49 of Set 1 : hilo
# Processing Record 50 of Set 1 : port hedland
# Processing Record 0 of Set 2 : ternate
# Processing Record 1 of Set 2 : sitka
# Processing Record 2 of Set 2 : vaini
# Processing Record 3 of Set 2 : saquarema
# Processing Record 4 of Set 2 : tuatapere
# Processing Record 5 of Set 2 : bethel
# Processing Record 6 of Set 2 : cermik
# Processing Record 7 of Set 2 : hermanus
# Processing Record 8 of Set 2 : luderitz
# Processing Record 9 of Set 2 : saint-philippe
# Processing Record 10 of Set 2 : mataura
# Processing Record 11 of Set 2 : tshikapa
# Processing Record 12 of Set 2 : takoradi
# Processing Record 13 of Set 2 : san patricio
# Processing Record 14 of Set 2 : sencha
# Processing Record 15 of Set 2 : sisimiut
# Processing Record 16 of Set 2 : marawi
# Processing Record 17 of Set 2 : demba
# Processing Record 18 of Set 2 : ouallam
# Processing Record 19 of Set 2 : murgab
# Processing Record 20 of Set 2 : mindelo
# Processing Record 21 of Set 2 : torbay
# Processing Record 22 of Set 2 : hasaki
# Processing Record 23 of Set 2 : calvinia
# Processing Record 24 of Set 2 : sayyan
# City not found. Skipping...
# Processing Record 25 of Set 2 : qaanaaq
# City not found. Skipping...
# Processing Record 26 of Set 2 : port elizabeth
# Processing Record 27 of Set 2 : saint anthony
# Processing Record 28 of Set 2 : arlit
# Processing Record 29 of Set 2 : jamestown
# Processing Record 30 of Set 2 : dikson
# Processing Record 31 of Set 2 : hovd
# Processing Record 32 of Set 2 : ilulissat
# Processing Record 33 of Set 2 : chapadinha
# Processing Record 34 of Set 2 : vestmanna
# Processing Record 35 of Set 2 : ribeira grande
# Processing Record 36 of Set 2 : arraial do cabo
# Processing Record 37 of Set 2 : grand baie
# Processing Record 38 of Set 2 : tooele
# City not found. Skipping...
# Processing Record 39 of Set 2 : axim
# Processing Record 40 of Set 2 : fairbanks
# Processing Record 41 of Set 2 : bucerias
# Processing Record 42 of Set 2 : dunmore east
# Processing Record 43 of Set 2 : vila velha
# City not found. Skipping...
# Processing Record 44 of Set 2 : berlevag
# Processing Record 45 of Set 2 : iqaluit
# Processing Record 46 of Set 2 : okhotsk
# Processing Record 47 of Set 2 : edd
# Processing Record 48 of Set 2 : sobolevo
# Processing Record 49 of Set 2 : tazovskiy
# Processing Record 50 of Set 2 : alice springs
# Processing Record 0 of Set 3 : husavik
# Processing Record 1 of Set 3 : vanavara
# Processing Record 2 of Set 3 : kaniama
# Processing Record 3 of Set 3 : salalah
# Processing Record 4 of Set 3 : thinadhoo
# Processing Record 5 of Set 3 : pevek
# City not found. Skipping...
# Processing Record 6 of Set 3 : bengkulu
# Processing Record 7 of Set 3 : severo-kurilsk
# Processing Record 8 of Set 3 : provost
# Processing Record 9 of Set 3 : mpika
# Processing Record 10 of Set 3 : novyy urengoy
# Processing Record 11 of Set 3 : kurilsk
# Processing Record 12 of Set 3 : bambous virieux
# Processing Record 13 of Set 3 : bubaque
# Processing Record 14 of Set 3 : lata
# Processing Record 15 of Set 3 : codrington
# Processing Record 16 of Set 3 : saint-pierre
# City not found. Skipping...
# Processing Record 17 of Set 3 : hithadhoo
# Processing Record 18 of Set 3 : cape town
# Processing Record 19 of Set 3 : mwene-ditu
# Processing Record 20 of Set 3 : werder
# Processing Record 21 of Set 3 : senanga
# Processing Record 22 of Set 3 : avarua
# Processing Record 23 of Set 3 : victoria
# Processing Record 24 of Set 3 : esperance
# Processing Record 25 of Set 3 : ballangen
# Processing Record 26 of Set 3 : lavrentiya
# Processing Record 27 of Set 3 : price
# Processing Record 28 of Set 3 : sao filipe
# Processing Record 29 of Set 3 : stornoway
# Processing Record 30 of Set 3 : kargasok
# City not found. Skipping...
# Processing Record 31 of Set 3 : noumea
# Processing Record 32 of Set 3 : dinguiraye
# Processing Record 33 of Set 3 : la serena
# Processing Record 34 of Set 3 : tuktoyaktuk
# Processing Record 35 of Set 3 : coquimbo
# Processing Record 36 of Set 3 : ixtapa
# Processing Record 37 of Set 3 : carnarvon
# Processing Record 38 of Set 3 : norman wells
# Processing Record 39 of Set 3 : katsuura
# City not found. Skipping...
# Processing Record 40 of Set 3 : guaruja
# Processing Record 41 of Set 3 : cayenne
# Processing Record 42 of Set 3 : hervey bay
# Processing Record 43 of Set 3 : butaritari
# Processing Record 44 of Set 3 : opuwo
# City not found. Skipping...
# Processing Record 45 of Set 3 : batagay-alyta
# City not found. Skipping...
# Processing Record 46 of Set 3 : tura
# Processing Record 47 of Set 3 : zaraza
# Processing Record 48 of Set 3 : port keats
# Processing Record 49 of Set 3 : mount isa
# Processing Record 50 of Set 3 : kaeo
# Processing Record 0 of Set 4 : bilibino
# Processing Record 1 of Set 4 : boa vista
# Processing Record 2 of Set 4 : quatre cocos
# Processing Record 3 of Set 4 : coahuayana
# Processing Record 4 of Set 4 : lebu
# Processing Record 5 of Set 4 : dingle
# Processing Record 6 of Set 4 : grand gaube
# Processing Record 7 of Set 4 : kez
# Processing Record 8 of Set 4 : bafata
# City not found. Skipping...
# Processing Record 9 of Set 4 : rabo de peixe
# Processing Record 10 of Set 4 : college
# Processing Record 11 of Set 4 : pisco
# Processing Record 12 of Set 4 : bonthe
# City not found. Skipping...
# Processing Record 13 of Set 4 : guia lopes da laguna
# Processing Record 14 of Set 4 : new norfolk
# Processing Record 15 of Set 4 : kruisfontein
# Processing Record 16 of Set 4 : moron
# Processing Record 17 of Set 4 : buin
# Processing Record 18 of Set 4 : raga
# Processing Record 19 of Set 4 : alofi
# Processing Record 20 of Set 4 : kavieng
# City not found. Skipping...
# Processing Record 21 of Set 4 : kununurra
# Processing Record 22 of Set 4 : leningradskiy
# Processing Record 23 of Set 4 : touros
# Processing Record 24 of Set 4 : mikhaylov
# Processing Record 25 of Set 4 : kletnya
# Processing Record 26 of Set 4 : athens
# City not found. Skipping...
# Processing Record 27 of Set 4 : kaitangata
# City not found. Skipping...
# Processing Record 28 of Set 4 : polunochnoye
# Processing Record 29 of Set 4 : soure
# Processing Record 30 of Set 4 : flinders
# Processing Record 31 of Set 4 : kavaratti
# Processing Record 32 of Set 4 : tiksi
# Processing Record 33 of Set 4 : east london
# Processing Record 34 of Set 4 : whitehorse
# Processing Record 35 of Set 4 : cockburn town
# Processing Record 36 of Set 4 : bulgan
# Processing Record 37 of Set 4 : oistins
# Processing Record 38 of Set 4 : de-kastri
# Processing Record 39 of Set 4 : grindavik
# Processing Record 40 of Set 4 : udachnyy
# Processing Record 41 of Set 4 : kijang
# Processing Record 42 of Set 4 : puerto escondido
# Processing Record 43 of Set 4 : provideniya
# Processing Record 44 of Set 4 : ossora
# City not found. Skipping...
# Processing Record 45 of Set 4 : enshi
# Processing Record 46 of Set 4 : moree
# Processing Record 47 of Set 4 : saint-augustin
# Processing Record 48 of Set 4 : jalu
# Processing Record 49 of Set 4 : port shepstone
# Processing Record 50 of Set 4 : macas
# Processing Record 0 of Set 5 : bela
# Processing Record 1 of Set 5 : broken hill
# Processing Record 2 of Set 5 : zapolyarnyy
# Processing Record 3 of Set 5 : luba
# Processing Record 4 of Set 5 : biak
# Processing Record 5 of Set 5 : adrar
# Processing Record 6 of Set 5 : yulara
# Processing Record 7 of Set 5 : moreira sales
# Processing Record 8 of Set 5 : azle
# Processing Record 9 of Set 5 : georgetown
# Processing Record 10 of Set 5 : faanui
# Processing Record 11 of Set 5 : nome
# Processing Record 12 of Set 5 : akyab
# Processing Record 13 of Set 5 : rio grande
# Processing Record 14 of Set 5 : kangaatsiaq
# Processing Record 15 of Set 5 : bilma
# Processing Record 16 of Set 5 : palmer
# Processing Record 17 of Set 5 : niquero
# Processing Record 18 of Set 5 : tautira
# Processing Record 19 of Set 5 : oussouye
# Processing Record 20 of Set 5 : acarau
# Processing Record 21 of Set 5 : waddan
# Processing Record 22 of Set 5 : florianopolis
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 5 : ust-kuyga
# City not found. Skipping...
# Processing Record 24 of Set 5 : ketchikan
# Processing Record 25 of Set 5 : laguna
# Processing Record 26 of Set 5 : casas grandes
# Processing Record 27 of Set 5 : praia da vitoria
# Processing Record 28 of Set 5 : north vanlaiphai
# Processing Record 29 of Set 5 : tuy hoa
# Processing Record 30 of Set 5 : aloleng
# Processing Record 31 of Set 5 : terrace bay
# Processing Record 32 of Set 5 : phibun mangsahan
# Processing Record 33 of Set 5 : urumqi
# Processing Record 34 of Set 5 : lichuan
# Processing Record 35 of Set 5 : leh
# Processing Record 36 of Set 5 : korla
# Processing Record 37 of Set 5 : tasiilaq
# Processing Record 38 of Set 5 : pangai
# Processing Record 39 of Set 5 : wanning
# Processing Record 40 of Set 5 : fujin
# Processing Record 41 of Set 5 : suntar
# Processing Record 42 of Set 5 : north bend
# Processing Record 43 of Set 5 : wajir
# Processing Record 44 of Set 5 : villa carlos paz
# City not found. Skipping...
# Processing Record 45 of Set 5 : olafsvik
# Processing Record 46 of Set 5 : hami
# Processing Record 47 of Set 5 : faya
# Processing Record 48 of Set 5 : padang
# Processing Record 49 of Set 5 : garowe
# City not found. Skipping...
# Processing Record 50 of Set 5 : pangnirtung
# Processing Record 0 of Set 6 : port angeles
# Processing Record 1 of Set 6 : magole
# Processing Record 2 of Set 6 : marfino
# Processing Record 3 of Set 6 : sujiatun
# Processing Record 4 of Set 6 : oban
# Processing Record 5 of Set 6 : clyde river
# Processing Record 6 of Set 6 : bazarnyye mataki
# Processing Record 7 of Set 6 : council bluffs
# Processing Record 8 of Set 6 : frontera
# Processing Record 9 of Set 6 : yaan
# Processing Record 10 of Set 6 : rawson
# Processing Record 11 of Set 6 : riyadh
# Processing Record 12 of Set 6 : harper
# Processing Record 13 of Set 6 : srednekolymsk
# City not found. Skipping...
# Processing Record 14 of Set 6 : kinel-cherkassy
# Processing Record 15 of Set 6 : morondava
# Processing Record 16 of Set 6 : road town
# Processing Record 17 of Set 6 : komsomolskiy
# Processing Record 18 of Set 6 : panjab
# Processing Record 19 of Set 6 : bardiyah
# Processing Record 20 of Set 6 : ambovombe
# Processing Record 21 of Set 6 : pringsewu
# City not found. Skipping...
# Processing Record 22 of Set 6 : neiafu
# City not found. Skipping...
# Processing Record 23 of Set 6 : mandya
# Processing Record 24 of Set 6 : namatanai
# Processing Record 25 of Set 6 : san carlos de bariloche
# Processing Record 26 of Set 6 : balaghat
# Processing Record 27 of Set 6 : juazeirinho
# Processing Record 28 of Set 6 : katherine
# Processing Record 29 of Set 6 : weiden
# Processing Record 30 of Set 6 : pavilosta
# City not found. Skipping...
# Processing Record 31 of Set 6 : sioux lookout
# Processing Record 32 of Set 6 : chuy
# Processing Record 33 of Set 6 : pacific grove
# City not found. Skipping...
# Processing Record 34 of Set 6 : gorontalo
# Processing Record 35 of Set 6 : murray bridge
# Processing Record 36 of Set 6 : saraland
# Processing Record 37 of Set 6 : visby
# Processing Record 38 of Set 6 : pokhara
# Processing Record 39 of Set 6 : elk city
# Processing Record 40 of Set 6 : tabuk
# Processing Record 41 of Set 6 : ayan
# City not found. Skipping...
# Processing Record 42 of Set 6 : vila franca do campo
# Processing Record 43 of Set 6 : marrakesh
# Processing Record 44 of Set 6 : hofn
# City not found. Skipping...
# Processing Record 45 of Set 6 : chaumont
# Processing Record 46 of Set 6 : haines junction
# Processing Record 47 of Set 6 : maniitsoq
# Processing Record 48 of Set 6 : mahibadhoo
# City not found. Skipping...
# Processing Record 49 of Set 6 : sept-iles
# Processing Record 50 of Set 6 : turukhansk
# Processing Record 0 of Set 7 : aswan
# Processing Record 1 of Set 7 : kahului
# Processing Record 2 of Set 7 : newport
# Processing Record 3 of Set 7 : dubbo
# Processing Record 4 of Set 7 : vostok
# Processing Record 5 of Set 7 : atar
# Processing Record 6 of Set 7 : aluksne
# Processing Record 7 of Set 7 : yar-sale
# Processing Record 8 of Set 7 : mandalgovi
# Processing Record 9 of Set 7 : ishigaki
# Processing Record 10 of Set 7 : cuamba
# Processing Record 11 of Set 7 : morros
# Processing Record 12 of Set 7 : yarqa
# Processing Record 13 of Set 7 : west monroe
# Processing Record 14 of Set 7 : marsa matruh
# Processing Record 15 of Set 7 : lorengau
# Processing Record 16 of Set 7 : sungaipenuh
# Processing Record 17 of Set 7 : binghamton
# Processing Record 18 of Set 7 : mont-dore
# City not found. Skipping...
# Processing Record 19 of Set 7 : chongoyape
# Processing Record 20 of Set 7 : camabatela
# Processing Record 21 of Set 7 : tahe
# Processing Record 22 of Set 7 : banjarmasin
# Processing Record 23 of Set 7 : east wenatchee bench
# Processing Record 24 of Set 7 : mangrol
# Processing Record 25 of Set 7 : minna
# Processing Record 26 of Set 7 : coihaique
# Processing Record 27 of Set 7 : narasannapeta
# Processing Record 28 of Set 7 : bemidji
# Processing Record 29 of Set 7 : stephenville
# Processing Record 30 of Set 7 : san vicente
# Processing Record 31 of Set 7 : vao
# Processing Record 32 of Set 7 : tombouctou
# Processing Record 33 of Set 7 : sal rei
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 7 : baracoa
# Processing Record 35 of Set 7 : lhokseumawe
# Processing Record 36 of Set 7 : waingapu
# Processing Record 37 of Set 7 : saskylakh
# Processing Record 38 of Set 7 : hualmay
# Processing Record 39 of Set 7 : mulege
# Processing Record 40 of Set 7 : palu
# Processing Record 41 of Set 7 : ciudad real
# Processing Record 42 of Set 7 : zeya
# Processing Record 43 of Set 7 : slave lake
# Processing Record 44 of Set 7 : krivosheino
# Processing Record 45 of Set 7 : kismayo
# Processing Record 46 of Set 7 : hamilton
# Processing Record 47 of Set 7 : fortuna
# Processing Record 48 of Set 7 : piossasco
# Processing Record 49 of Set 7 : chaman
# Processing Record 50 of Set 7 : uglekamensk
# Processing Record 0 of Set 8 : ust-nera
# Processing Record 1 of Set 8 : santa marta
# Processing Record 2 of Set 8 : vanimo
# Processing Record 3 of Set 8 : geraldton
# Processing Record 4 of Set 8 : biltine
# City not found. Skipping...
# Processing Record 5 of Set 8 : nicoya
# Processing Record 6 of Set 8 : hambantota
# Processing Record 7 of Set 8 : cabo san lucas
# Processing Record 8 of Set 8 : tamiahua
# Processing Record 9 of Set 8 : cidreira
# Processing Record 10 of Set 8 : los llanos de aridane
# Processing Record 11 of Set 8 : portland
# Processing Record 12 of Set 8 : nanakuli
# Processing Record 13 of Set 8 : muros
# Processing Record 14 of Set 8 : glenwood springs
# Processing Record 15 of Set 8 : caravelas
# Processing Record 16 of Set 8 : isangel
# Processing Record 17 of Set 8 : celestun
# Processing Record 18 of Set 8 : dunedin
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 8 : porto santo
# Processing Record 20 of Set 8 : tairua
# Processing Record 21 of Set 8 : roslavl
# Processing Record 22 of Set 8 : shingu
# Processing Record 23 of Set 8 : souillac
# Processing Record 24 of Set 8 : general roca
# Processing Record 25 of Set 8 : taoudenni
# Processing Record 26 of Set 8 : tual
# Processing Record 27 of Set 8 : pran buri
# Processing Record 28 of Set 8 : gibara
# Processing Record 29 of Set 8 : paamiut
# Processing Record 30 of Set 8 : yevlax
# Processing Record 31 of Set 8 : cururupu
# City not found. Skipping...
# Processing Record 32 of Set 8 : xai-xai
# Processing Record 33 of Set 8 : prince rupert
# Processing Record 34 of Set 8 : urengoy
# Processing Record 35 of Set 8 : ponta delgada
# Processing Record 36 of Set 8 : sambava
# Processing Record 37 of Set 8 : ostrovnoy
# Processing Record 38 of Set 8 : samarai
# Processing Record 39 of Set 8 : te anau
# Processing Record 40 of Set 8 : winslow
# Processing Record 41 of Set 8 : port-gentil
# City not found. Skipping...
# Processing Record 42 of Set 8 : miura
# Processing Record 43 of Set 8 : mantua
# Processing Record 44 of Set 8 : vilyuysk
# Processing Record 45 of Set 8 : batagay
# Processing Record 46 of Set 8 : porto novo
# Processing Record 47 of Set 8 : chokurdakh
# Processing Record 48 of Set 8 : auki
# City not found. Skipping...
# Processing Record 49 of Set 8 : tessalit
# Processing Record 50 of Set 8 : ilinskiy
# Processing Record 0 of Set 9 : ekibastuz
# Processing Record 1 of Set 9 : san clemente
# Processing Record 2 of Set 9 : ochamchira
# Processing Record 3 of Set 9 : galveston
# Processing Record 4 of Set 9 : buta
# Processing Record 5 of Set 9 : cherskiy
# Processing Record 6 of Set 9 : asyut
# Processing Record 7 of Set 9 : cajamarca
# Processing Record 8 of Set 9 : saldanha
# Processing Record 9 of Set 9 : guerrero negro
# Processing Record 10 of Set 9 : aksu
# Processing Record 11 of Set 9 : longyearbyen
# Processing Record 12 of Set 9 : lompoc
# Processing Record 13 of Set 9 : ahipara
# Processing Record 14 of Set 9 : kathu
# Processing Record 15 of Set 9 : christchurch
# City not found. Skipping...
# Processing Record 16 of Set 9 : bandarbeyla
# Processing Record 17 of Set 9 : borogontsy
# Processing Record 18 of Set 9 : aden
# Processing Record 19 of Set 9 : klyuchi
# Processing Record 20 of Set 9 : le port
# Processing Record 21 of Set 9 : the valley
# Processing Record 22 of Set 9 : haukipudas
# Processing Record 23 of Set 9 : port lincoln
# Processing Record 24 of Set 9 : miri
# Processing Record 25 of Set 9 : pedernales
# Processing Record 26 of Set 9 : mount gambier
# City not found. Skipping...
# Processing Record 27 of Set 9 : cairns
# Processing Record 28 of Set 9 : ferkessedougou
# Processing Record 29 of Set 9 : ancud
# Processing Record 30 of Set 9 : wuning
# Processing Record 31 of Set 9 : seoul
# Processing Record 32 of Set 9 : saint-francois
# Processing Record 33 of Set 9 : aksarka
# Processing Record 34 of Set 9 : thunder bay
# Processing Record 35 of Set 9 : lanzhou
# Processing Record 36 of Set 9 : magadan
# City not found. Skipping...
# Processing Record 37 of Set 9 : cananeia
# Processing Record 38 of Set 9 : kaffrine
# Processing Record 39 of Set 9 : port macquarie
# Processing Record 40 of Set 9 : lagoa
# Processing Record 41 of Set 9 : cam ranh
# Processing Record 42 of Set 9 : pervoye maya
# Processing Record 43 of Set 9 : svetlyy
# City not found. Skipping...
# Processing Record 44 of Set 9 : sueyoshi
# Processing Record 45 of Set 9 : batemans bay
# Processing Record 46 of Set 9 : otradnoye
# Processing Record 47 of Set 9 : san quintin
# Processing Record 48 of Set 9 : asgabat
# City not found. Skipping...
# Processing Record 49 of Set 9 : boysun
# Processing Record 50 of Set 9 : buarcos
# Processing Record 0 of Set 10 : carutapera
# Processing Record 1 of Set 10 : bay roberts
# Processing Record 2 of Set 10 : lamu
# Processing Record 3 of Set 10 : yanam
# Processing Record 4 of Set 10 : luau
# Processing Record 5 of Set 10 : sakakah
# Processing Record 6 of Set 10 : pietersburg
# Processing Record 7 of Set 10 : kidal
# Processing Record 8 of Set 10 : nishihara
# Processing Record 9 of Set 10 : yenagoa
# Processing Record 10 of Set 10 : mae ramat
# Processing Record 11 of Set 10 : bolu
# Processing Record 12 of Set 10 : hammerfest
# Processing Record 13 of Set 10 : novonukutskiy
# Processing Record 14 of Set 10 : akhisar
# Processing Record 15 of Set 10 : pinheiro
# Processing Record 16 of Set 10 : pengcheng
# Processing Record 17 of Set 10 : mehamn
# Processing Record 18 of Set 10 : kaili
# Processing Record 19 of Set 10 : ocos
# Processing Record 20 of Set 10 : deputatskiy
# Processing Record 21 of Set 10 : yeniseysk
# Processing Record 22 of Set 10 : asau
# Processing Record 23 of Set 10 : la asuncion
# Processing Record 24 of Set 10 : dongsheng
# Processing Record 25 of Set 10 : rudbar
# Processing Record 26 of Set 10 : nelson bay
# City not found. Skipping...
# Processing Record 27 of Set 10 : domoni
# Processing Record 28 of Set 10 : fort nelson
# Processing Record 29 of Set 10 : barra do garcas
# Processing Record 30 of Set 10 : mount pleasant
# Processing Record 31 of Set 10 : camacha
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# ~\anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ConnectionResetError: [WinError 10054] An existing connection was forcibly closed by the remote host
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     723
# --> 724             retries = retries.increment(
#     725                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     402             if read is False or not self._is_method_retryable(method):
# --> 403                 raise six.reraise(type(error), error, _stacktrace)
#     404             elif read is not None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     420                 try:
# --> 421                     httplib_response = conn.getresponse()
#     422                 except BaseException as e:
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in getresponse(self)
#    1331             try:
# -> 1332                 response.begin()
#    1333             except ConnectionError:
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in begin(self)
#     302         while True:
# --> 303             version, status, reason = self._read_status()
#     304             if status != CONTINUE:
#
# ~\anaconda3\envs\PythonData\lib\http\client.py in _read_status(self)
#     263     def _read_status(self):
# --> 264         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     265         if len(line) > _MAXLINE:
#
# ~\anaconda3\envs\PythonData\lib\socket.py in readinto(self, b)
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-4-bd5405d20769> in <module>
#      22 for index, city in enumerate(cities, start = 1):
#      23     try:
# ---> 24         response = requests.get(query_url + city).json()
#      25         city_name_list.append(response["name"])
#      26         cloudiness_list.append(response["clouds"]["all"])
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     528         }
#     529         send_kwargs.update(settings)
# --> 530         resp = self.send(prep, **send_kwargs)
#     531
#     532         return resp
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     641
#     642         # Send the request
# --> 643         r = adapter.send(request, **kwargs)
#     644
#     645         # Total elapsed time of the request (approximately)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(10054, 'An existing connection was forcibly closed by the remote host', None, 10054, None))

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a panda data frame using data retrieved
weather_df = pd.DataFrame({ 
                "City" : city_name_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Humidity" : humidity_list,
                "Cloudiness" : cloudiness_list,
                "Wind Speed" : wind_speed_list,
                "Country" : country_list,
                "Date" : date_list             
       
})

# %%
#  Count data
weather_df.count()
# Out:
# City          490
# Lat           490
# Lng           490
# Max Temp      490
# Humidity      490
# Cloudiness    490
# Wind Speed    490
# Country       490
# Date          490
# dtype: int64

# %%
# Display weather DataFrame
weather_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Atuona  -9.80 -139.03     26.33        75          37        7.85
# 1      Rikitea -23.12 -134.97     23.02        82         100        6.76
# 2   Itupiranga  -5.13  -49.33     26.00        69           1        0.42
# 3      Kodinsk  58.69   99.18     10.86        66          90        4.00
# 4  Yellowknife  62.46 -114.35     20.00        40          75        3.60
#
#   Country        Date
# 0      PF  1595028797
# 1      PF  1595028908
# 2      BR  1595029082
# 3      RU  1595029082
# 4      CA  1595028744

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# use the .inspect function

# %%
#  Get the indices of cities that have humidity over 100%.
#weather_df_hum = weather_df([Humidity] > '100')
#weather_df_hum

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Extract relevant fields from the data frame


# Export the City_Data into a csv
weather_df.to_csv("output_data/cities.csv", index = False)

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_df["Lat"], weather_df["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Max Temperature (04/01/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel("Max Temperature (F)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Create Latitude vs. Temperature Plot scatter plot
plt.scatter(weather_df["Lat"], weather_df["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Humidity (04/01/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel(" Humidity (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Create Latitude vs. Cloudiness Plot scatter plot
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Cloudiness (04/01/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel(" Cloudiness (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Create Latitude vs. Wind Speed Plot scatter plot
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], facecolor = "steelblue", edgecolor = "black")

# Set title
plt.title("City Latitude vs. Wind Speed (04/01/20)")

# Set x axis label
plt.xlabel("Laitude")

# Set y axis label
plt.ylabel(" Wind Speed (%)")

# Set grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Save the plotted figure as .pngs
plt.savefig("../Images/City Latitude vs Wind Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemisphere = weather_df.loc[weather_df["Lat"] >= 0]
southern_hemisphere = weather_df.loc[weather_df["Lat"] <= 0]

# Define function for creating linear agression and scatter plot
def linear_agression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Define a fuction for annotating
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.73

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Max Temp"])

# Call an function #2
annotate(equation, 0, 0)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.8

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, 40, 15)

# Set a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.01

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Call an function #2
annotate(equation, -40, 50)

# Set title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Humidity (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.03

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, 30, 40)

# Set a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.08

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Call an function #2
annotate(equation, -30, 40)

# Set a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Cloudiness (%)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.08

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, 40, 20)

# Set  title
plt.title("Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Northern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.04

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Call an function #1
equation = linear_agression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Call an function #2
annotate(equation, -30, 15)

# Set  title
plt.title("Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Wind Speed (mph)")

# Save the figure
plt.savefig("../Images/Southern Hemisphere - Wind Speed vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.05
